# %% [markdown]
# <a href="https://colab.research.google.com/github/thamiressouza-ds/first_step/blob/main/novo-grafico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importacao de bibliotecas
import random
import matplotlib.pyplot as plt

# Gerar uma lista com 10 numeros aleatorios entre 1 e 100
dados = [random.randint(1, 100) for _ in range(10)]

# Exibir a lista gerada
print('Lista de dados:', dados)

# Plotar os dados
plt.plot(dados, marker='o')   #marcador em cada ponto para melhor visualização
plt.title('Gráfico de Números Aleatórios')
plt.xlabel('Índice')
plt.ylabel('Valor')
plt.grid(True)
plt.show()
# Out:
# Lista de dados: [20, 61, 22, 60, 42, 31, 60, 29, 83, 96]
